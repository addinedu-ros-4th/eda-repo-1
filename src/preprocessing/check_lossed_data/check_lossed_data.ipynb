# %% [markdown]
# ### check lossed crawling flight data

# %%
import pandas as pd

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

# %%
bang26_raw = pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_bangkok_26.csv' , names = col_names, encoding="utf-8")
bang27_raw = pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_bangkok_27.csv' , names = col_names, encoding="utf-8")

dana26_raw = pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_danang_26.csv' , names = col_names, encoding="utf-8")
dana27_raw = pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_danang_27.csv' , names = col_names, encoding="utf-8")

osaka26_raw = pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_osaka_26.csv' , names = col_names, encoding="utf-8")
osaka27_raw = pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_osaka_27.csv' , names = col_names, encoding="utf-8")

# %%
all_times = pd.date_range(start=bang26_raw['추출시간'].min(), end=bang26_raw['추출시간'].max(), freq='30T')
missing_times = set(all_times) - set(pd.to_datetime(bang26_raw['추출시간']))
# print("손실된 시간:")
# print(sorted(missing_times))

missing_times_list = sorted(missing_times)
for i in range(0, len(missing_times_list), 2):
    print(missing_times_list[i:i + 2])
# Out:
# [Timestamp('2024-01-20 03:30:00'), Timestamp('2024-01-20 04:00:00')]
# [Timestamp('2024-01-20 04:30:00'), Timestamp('2024-01-20 05:00:00')]
# [Timestamp('2024-01-20 05:30:00'), Timestamp('2024-01-20 06:00:00')]
# [Timestamp('2024-01-20 06:30:00'), Timestamp('2024-01-20 07:00:00')]
# [Timestamp('2024-01-20 07:30:00'), Timestamp('2024-01-20 08:00:00')]
# [Timestamp('2024-01-20 08:30:00'), Timestamp('2024-01-20 09:00:00')]
# [Timestamp('2024-01-20 09:30:00'), Timestamp('2024-01-20 10:00:00')]
# [Timestamp('2024-01-20 10:30:00'), Timestamp('2024-01-20 11:00:00')]
# [Timestamp('2024-01-20 11:30:00'), Timestamp('2024-01-20 12:00:00')]

# %%
bang26_raw['추출시간'].unique()
# Out:
# array(['2024-01-19 15:00:00', '2024-01-19 15:30:00',
#        '2024-01-19 16:00:00', '2024-01-19 16:30:00',
#        '2024-01-19 17:00:00', '2024-01-19 17:30:00',
#        '2024-01-19 18:00:00', '2024-01-19 18:30:00',
#        '2024-01-19 19:00:00', '2024-01-19 19:30:00',
#        '2024-01-19 20:00:00', '2024-01-19 20:30:00',
#        '2024-01-19 21:00:00', '2024-01-19 21:30:00',
#        '2024-01-19 22:00:00', '2024-01-19 22:30:00',
#        '2024-01-19 23:00:00', '2024-01-19 23:30:00',
#        '2024-01-20 00:00:00', '2024-01-20 00:30:00',
#        '2024-01-20 01:00:00', '2024-01-20 01:30:00',
#        '2024-01-20 02:00:00', '2024-01-20 02:30:00',
#        '2024-01-20 03:00:00', '2024-01-20 12:30:00',
#        '2024-01-20 13:00:00', '2024-01-20 13:30:00',
#        '2024-01-20 14:00:00', '2024-01-20 14:30:00',
#        '2024-01-20 15:00:00', '2024-01-20 15:30:00',
#        '2024-01-20 16:00:00', '2024-01-20 16:30:00',
#        '2024-01-20 17:00:00', '2024-01-20 17:30:00',
# ...
