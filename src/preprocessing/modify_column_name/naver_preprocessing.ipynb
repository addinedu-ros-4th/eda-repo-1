# %%
import pandas as pd
import numpy as np 
import datetime
import os

# %% [markdown]
# ## 손실 데이터를 보완한 data의 경로 가져오기

# %%
naver_bangkok_26 = '/'
naver_bangkok_27 = '/'
naver_danang_26 = '/'
naver_danang_27 = '/'
naver_osaka_26 = '/'
naver_osaka_27 = '/'

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

df1 = pd.read_csv(f'/', names = col_names, encoding="utf-8")
df1['편명'] = None

# 추출시간 date_time 형으로
df1['추출시간'] = pd.to_datetime(df1['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
df1['가격'] = df1['가격'].str.replace(',', '').str.replace('원', '').astype(int)

df1
# Out:
#             항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0        에어프레미아  17:10  ICN  21:15  BKK   직항  06시간 05분    편도  289400
# 1     타이에어아시아엑스  11:20  ICN  15:15  BKK   직항  05시간 55분    편도  303300
# 2     타이에어아시아엑스  16:25  ICN  20:35  BKK   직항  06시간 10분    편도  303300
# 3          에어부산  16:50  ICN  21:10  BKK   직항  06시간 20분    편도  345383
# 4         티웨이항공  19:50  ICN  00:10  BKK   직항  06시간 20분    편도  353790
# ...         ...    ...  ...    ...  ...  ...       ...   ...     ...
# 1937       대한항공  09:15  ICN  13:15  BKK   직항  06시간 00분    편도  656016
# 1938       대한항공  17:10  ICN  21:10  BKK   직항  06시간 00분    편도  828361
# 1939     아시아나항공  09:35  ICN  13:30  BKK   직항  05시간 55분    편도  860974
# 1940     아시아나항공  10:50  ICN  14:45  BKK   직항  05시간 55분    편도  860974
# 1941     아시아나항공  17:30  ICN  21:25  BKK   직항  05시간 55분    편도  861571
#
#                     추출시간    편명
# 0    2024-01-20 19:00:00  None
# 1    2024-01-20 19:00:00  None
# 2    2024-01-20 19:00:00  None
# ...

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

df2 = pd.read_csv(f'/', names = col_names, encoding="utf-8")
df2['편명'] = None

# 추출시간 date_time 형으로
df2['추출시간'] = pd.to_datetime(df2['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
df2['가격'] = df2['가격'].str.replace(',', '').str.replace('원', '').astype(int)

df2
# Out:
#             항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0     타이에어아시아엑스  11:20  ICN  15:20  BKK   직항  06시간 00분    편도  278500
# 1     타이에어아시아엑스  16:25  ICN  20:35  BKK   직항  06시간 10분    편도  278500
# 2        에어프레미아  17:10  ICN  21:15  BKK   직항  06시간 05분    편도  289400
# 3          에어부산  16:50  ICN  21:10  BKK   직항  06시간 20분    편도  347700
# 4         티웨이항공  19:50  ICN  00:10  BKK   직항  06시간 20분    편도  353790
# ...         ...    ...  ...    ...  ...  ...       ...   ...     ...
# 1928       대한항공  09:15  ICN  13:15  BKK   직항  06시간 00분    편도  527041
# 1929       대한항공  17:10  ICN  21:10  BKK   직항  06시간 00분    편도  828361
# 1930     아시아나항공  10:50  ICN  14:45  BKK   직항  05시간 55분    편도  862256
# 1931     아시아나항공  09:35  ICN  13:30  BKK   직항  05시간 55분    편도  866379
# 1932     아시아나항공  17:30  ICN  21:25  BKK   직항  05시간 55분    편도  866379
#
#                     추출시간    편명
# 0    2024-01-20 19:00:00  None
# 1    2024-01-20 19:00:00  None
# 2    2024-01-20 19:00:00  None
# ...

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

df3 = pd.read_csv(f'/', names = col_names, encoding="utf-8")
df3['편명'] = None

# 추출시간 date_time 형으로
df3['추출시간'] = pd.to_datetime(df3['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
df3['가격'] = df3['가격'].str.replace(',', '').str.replace('원', '').astype(int)

df3
# Out:
#          항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0      이스타항공  20:55  ICN  23:45  DAD   직항  04시간 50분    편도  460966
# 1       에어서울  20:50  ICN  23:30  DAD   직항  04시간 40분    편도  492100
# 2      비엣젯항공  07:00  ICN  10:05  DAD   직항  05시간 05분    편도  510690
# 3      티웨이항공  07:45  ICN  10:55  DAD   직항  05시간 10분    편도  530127
# 4      티웨이항공  19:25  ICN  22:35  DAD   직항  05시간 10분    편도  530418
# ...      ...    ...  ...    ...  ...  ...       ...   ...     ...
# 1478   비엣젯항공  06:15  ICN  09:20  DAD   직항  05시간 05분    편도  585400
# 1479     진에어  21:10  ICN  00:25  DAD   직항  05시간 15분    편도  597900
# 1480    대한항공  18:30  ICN  21:45  DAD   직항  05시간 15분    편도  599300
# 1481  아시아나항공  18:45  ICN  21:50  DAD   직항  05시간 05분    편도  752500
# 1482    대한항공  11:10  ICN  14:15  DAD   직항  05시간 05분    편도  759700
#
#                     추출시간    편명
# 0    2024-01-20 19:00:00  None
# 1    2024-01-20 19:00:00  None
# 2    2024-01-20 19:00:00  None
# 3    2024-01-20 19:00:00  None
# ...

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

df4 = pd.read_csv(f'/', names = col_names, encoding="utf-8")
df4['편명'] = None

# 추출시간 date_time 형으로
df4['추출시간'] = pd.to_datetime(df4['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
df4['가격'] = df4['가격'].str.replace(',', '').str.replace('원', '').astype(int)

df4
# Out:
#          항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복       가격  \
# 0      이스타항공  22:50  ICN  01:30  DAD   직항  04시간 40분    편도   342860
# 1      이스타항공  20:55  ICN  23:45  DAD   직항  04시간 50분    편도   381767
# 2       에어서울  20:50  ICN  23:30  DAD   직항  04시간 40분    편도   425639
# 3      비엣젯항공  07:00  ICN  10:05  DAD   직항  05시간 05분    편도   510690
# 4      비엣젯항공  22:40  ICN  01:45  DAD   직항  05시간 05분    편도   510690
# ...      ...    ...  ...    ...  ...  ...       ...   ...      ...
# 1664     한에어  22:40  ICN  01:45  DAD   직항  05시간 05분    편도   700229
# 1665     한에어  06:15  ICN  09:20  DAD   직항  05시간 05분    편도   700229
# 1666  아시아나항공  18:45  ICN  21:50  DAD   직항  05시간 05분    편도   735300
# 1667    대한항공  11:10  ICN  14:15  DAD   직항  05시간 05분    편도   736191
# 1668   베트남항공  18:30  ICN  21:45  DAD   직항  05시간 15분    편도  1340363
#
#                     추출시간    편명
# 0    2024-01-20 19:00:00  None
# 1    2024-01-20 19:00:00  None
# 2    2024-01-20 19:00:00  None
# 3    2024-01-20 19:00:00  None
# ...

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

df5 = pd.read_csv(f'/', names = col_names, encoding="utf-8")
df5['편명'] = None

# 추출시간 date_time 형으로
df5['추출시간'] = pd.to_datetime(df5['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
df5['가격'] = df5['가격'].str.replace(',', '').str.replace('원', '').astype(int)

df5
# Out:
#         항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0      피치항공  10:35  ICN  12:20  KIX   직항  01시간 45분    편도  172381
# 1      피치항공  15:25  ICN  17:10  KIX   직항  01시간 45분    편도  172381
# 2      에어부산  15:35  ICN  17:30  KIX   직항  01시간 55분    편도  179028
# 3     이스타항공  15:05  ICN  17:00  KIX   직항  01시간 55분    편도  184298
# 4     티웨이항공  12:10  ICN  14:00  KIX   직항  01시간 50분    편도  187582
# ...     ...    ...  ...    ...  ...  ...       ...   ...     ...
# 3153   일본항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  360691
# 3154   일본항공  15:10  ICN  17:00  KIX   직항  01시간 50분    편도  360691
# 3155    ANA  14:10  ICN  15:50  KIX   직항  01시간 40분    편도  361501
# 3156    ANA  08:05  ICN  09:40  KIX   직항  01시간 35분    편도  361545
# 3157    ANA  19:10  ICN  20:55  KIX   직항  01시간 45분    편도  503140
#
#                     추출시간    편명
# 0    2024-01-20 19:00:00  None
# 1    2024-01-20 19:00:00  None
# 2    2024-01-20 19:00:00  None
# 3    2024-01-20 19:00:00  None
# ...

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']

df6 = pd.read_csv(f'/', names = col_names, encoding="utf-8")
df6['편명'] = None

# 추출시간 date_time 형으로
df6['추출시간'] = pd.to_datetime(df6['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
df6['가격'] = df6['가격'].str.replace(',', '').str.replace('원', '').astype(int)

df6
# Out:
#         항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0      피치항공  15:25  ICN  17:10  KIX   직항  01시간 45분    편도  154705
# 1      에어서울  15:20  ICN  17:00  KIX   직항  01시간 40분    편도  171172
# 2      피치항공  10:35  ICN  12:20  KIX   직항  01시간 45분    편도  171239
# 3      피치항공  07:30  ICN  09:15  KIX   직항  01시간 45분    편도  171239
# 4     이스타항공  15:05  ICN  17:00  KIX   직항  01시간 55분    편도  184866
# ...     ...    ...  ...    ...  ...  ...       ...   ...     ...
# 3403    ANA  19:10  ICN  20:55  KIX   직항  01시간 45분    편도  361443
# 3404    ANA  14:10  ICN  15:50  KIX   직항  01시간 40분    편도  361501
# 3405    ANA  08:05  ICN  09:40  KIX   직항  01시간 35분    편도  361545
# 3406   대한항공  08:00  ICN  09:45  KIX   직항  01시간 45분    편도  490340
# 3407   일본항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  502752
#
#                     추출시간    편명
# 0    2024-01-20 19:00:00  None
# 1    2024-01-20 19:00:00  None
# 2    2024-01-20 19:00:00  None
# 3    2024-01-20 19:00:00  None
# ...
