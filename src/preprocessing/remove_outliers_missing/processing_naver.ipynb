# %% [markdown]
# ## 네이버에 칼럼명 추가 및 편명 전처리 하는 코드

# %%
import pandas as pd
import numpy as np 
import datetime
import os

# %% [markdown]
# ### 방콕 26 네이버 raw

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']
# flight, date, flight_site

bang26_processed= pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_bangkok_26.csv', names = col_names, encoding="utf-8")


bang26_processed['추출시간'] = pd.to_datetime(bang26_processed['추출시간'])

# if '2024-01-20 12:30' before data? + 9hours
bang26_processed.loc[bang26_processed['추출시간'] < '2024-01-20 12:30', '추출시간'] += pd.Timedelta(hours=9)

bang26_processed['편명'] = None
bang26_processed['비행일자'] = '24.01.26(금)'
bang26_processed['사이트'] = 'naver'

# # 추출시간 date_time type
# bang26_processed['추출시간'] = pd.to_datetime(bang26_processed['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
bang26_processed['가격'] = bang26_processed['가격'].str.replace(',', '').str.replace('원', '').astype(int)

bang26_processed
# Out:
#             항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0        에어프레미아  17:10  ICN  21:15  BKK   직항  06시간 05분    편도  289400
# 1     타이에어아시아엑스  16:25  ICN  20:35  BKK   직항  06시간 10분    편도  297164
# 2     타이에어아시아엑스  11:20  ICN  15:15  BKK   직항  05시간 55분    편도  297368
# 3          에어부산  16:50  ICN  21:10  BKK   직항  06시간 20분    편도  344224
# 4         티웨이항공  19:50  ICN  00:10  BKK   직항  06시간 20분    편도  353790
# ...         ...    ...  ...    ...  ...  ...       ...   ...     ...
# 3515       대한항공  09:15  ICN  13:15  BKK   직항  06시간 00분    편도  656016
# 3516       대한항공  17:10  ICN  21:10  BKK   직항  06시간 00분    편도  823204
# 3517     아시아나항공  09:35  ICN  13:30  BKK   직항  05시간 55분    편도  867850
# 3518     아시아나항공  10:50  ICN  14:45  BKK   직항  05시간 55분    편도  867850
# 3519     아시아나항공  17:30  ICN  21:25  BKK   직항  05시간 55분    편도  908187
#
#                     추출시간    편명         비행일자    사이트
# 0    2024-01-20 00:00:00  None  24.01.26(금)  naver
# ...

# %% [markdown]
# ### 편명 넣기

# %%
#타이에어아시아엑스
bang26_processed.loc[(bang26_processed['항공사'] == '타이에어아시아엑스') & (bang26_processed['출발시간'] == '16:25'), '편명'] = 'XJ 709'
bang26_processed.loc[(bang26_processed['항공사'] == '타이에어아시아엑스') & (bang26_processed['출발시간'] == '15:15'), '편명'] = 'XJ 701'

#에어프레미아, 에어부산, 이스타, 진에어, 티웨이
bang26_processed.loc[(bang26_processed['항공사'] == '에어프레미아') & (bang26_processed['출발시간'] == '17:10'), '편명'] = 'YP 601'
bang26_processed.loc[(bang26_processed['항공사'] == '에어부산') & (bang26_processed['출발시간'] == '16:50'), '편명'] = 'BX 747'
bang26_processed.loc[(bang26_processed['항공사'] == '이스타항공') & (bang26_processed['출발시간'] == '17:05'), '편명'] = 'ZE 511'
bang26_processed.loc[(bang26_processed['항공사'] == '진에어') & (bang26_processed['출발시간'] == '17:10'), '편명'] = 'LJ 3'
bang26_processed.loc[(bang26_processed['항공사'] == '티웨이항공') & (bang26_processed['출발시간'] == '19:50'), '편명'] = 'TW 101'

#한에어
bang26_processed.loc[(bang26_processed['항공사'] == '한에어') & (bang26_processed['출발시간'] == '21:35'), '편명'] = 'H1 9859'
bang26_processed.loc[(bang26_processed['항공사'] == '한에어') & (bang26_processed['출발시간'] == '19:50'), '편명'] = 'H1 5850'
bang26_processed.loc[(bang26_processed['항공사'] == '한에어') & (bang26_processed['출발시간'] == '19:30'), '편명'] = 'H1 9857'

#타이항공
bang26_processed.loc[(bang26_processed['항공사'] == '타이항공') & (bang26_processed['출발시간'] == '17:30'), '편명'] = 'TG 653'
bang26_processed.loc[(bang26_processed['항공사'] == '타이항공') & (bang26_processed['출발시간'] == '10:50'), '편명'] = 'TG 657'
bang26_processed.loc[(bang26_processed['항공사'] == '타이항공') & (bang26_processed['출발시간'] == '09:35'), '편명'] = 'TG 659'

#제주항공
bang26_processed.loc[(bang26_processed['항공사'] == '제주항공') & (bang26_processed['출발시간'] == '21:35'), '편명'] = '7C 2205'
bang26_processed.loc[(bang26_processed['항공사'] == '제주항공') & (bang26_processed['출발시간'] == '19:30'), '편명'] = '7C 2203'

#대한항공
bang26_processed.loc[(bang26_processed['항공사'] == '대한항공') & (bang26_processed['출발시간'] == '17:10'), '편명'] = 'KE 5065'
bang26_processed.loc[(bang26_processed['항공사'] == '대한항공') & (bang26_processed['출발시간'] == '09:15'), '편명'] = 'KE 657'
bang26_processed.loc[(bang26_processed['항공사'] == '대한항공') & (bang26_processed['출발시간'] == '17:20'), '편명'] = 'KE 651'
bang26_processed.loc[(bang26_processed['항공사'] == '대한항공') & (bang26_processed['출발시간'] == '20:10'), '편명'] = 'KE 673'
bang26_processed.loc[(bang26_processed['항공사'] == '대한항공') & (bang26_processed['출발시간'] == '20:35'), '편명'] = 'KE 659'
bang26_processed.loc[(bang26_processed['항공사'] == '대한항공') & (bang26_processed['출발시간'] == '19:05'), '편명'] = 'KE 653'

#아시아나항공
bang26_processed.loc[(bang26_processed['항공사'] == '아시아나항공') & (bang26_processed['출발시간'] == '09:35'), '편명'] = 'OZ 6761'
bang26_processed.loc[(bang26_processed['항공사'] == '아시아나항공') & (bang26_processed['출발시간'] == '10:50'), '편명'] = 'OZ 6737'
bang26_processed.loc[(bang26_processed['항공사'] == '아시아나항공') & (bang26_processed['출발시간'] == '18:05'), '편명'] = 'OZ 741'
bang26_processed.loc[(bang26_processed['항공사'] == '아시아나항공') & (bang26_processed['출발시간'] == '20:20'), '편명'] = 'OZ 743'
bang26_processed.loc[(bang26_processed['항공사'] == '아시아나항공') & (bang26_processed['출발시간'] == '17:30'), '편명'] = 'OZ 6763'

# %%
bang26_processed
# Out:
#             항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0        에어프레미아  17:10  ICN  21:15  BKK   직항  06시간 05분    편도  289400
# 1     타이에어아시아엑스  16:25  ICN  20:35  BKK   직항  06시간 10분    편도  297164
# 2     타이에어아시아엑스  11:20  ICN  15:15  BKK   직항  05시간 55분    편도  297368
# 3          에어부산  16:50  ICN  21:10  BKK   직항  06시간 20분    편도  344224
# 4         티웨이항공  19:50  ICN  00:10  BKK   직항  06시간 20분    편도  353790
# ...         ...    ...  ...    ...  ...  ...       ...   ...     ...
# 3515       대한항공  09:15  ICN  13:15  BKK   직항  06시간 00분    편도  656016
# 3516       대한항공  17:10  ICN  21:10  BKK   직항  06시간 00분    편도  823204
# 3517     아시아나항공  09:35  ICN  13:30  BKK   직항  05시간 55분    편도  867850
# 3518     아시아나항공  10:50  ICN  14:45  BKK   직항  05시간 55분    편도  867850
# 3519     아시아나항공  17:30  ICN  21:25  BKK   직항  05시간 55분    편도  908187
#
#                     추출시간       편명         비행일자    사이트
# 0    2024-01-20 00:00:00   YP 601  24.01.26(금)  naver
# ...

# %%
# bang26_processed[bang26_processed['편명'].isna()]
bang26_processed = bang26_processed.dropna()

bang26_processed[bang26_processed['편명'].isna()]

bang26_processed.to_csv('/home/subin/project/최종 raw/네이버 한국시간으로 처리 후 데이터/bang26_processed.csv', index=False)

# %% [markdown]
# ### 방콕 27 네이버 raw

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']
#  편명, 비행일자, 사이트

bang27_processed= pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_bangkok_27.csv', names = col_names, encoding="utf-8")


bang27_processed['추출시간'] = pd.to_datetime(bang27_processed['추출시간'])

# '2024-01-20 12:30' 이전의 값에 대해서만 9시간을 더해줌
bang27_processed.loc[bang27_processed['추출시간'] < '2024-01-20 12:30', '추출시간'] += pd.Timedelta(hours=9)

bang27_processed['편명'] = None
bang27_processed['비행일자'] = '24.01.27(토)'
bang27_processed['사이트'] = 'naver'

# # 추출시간 date_time 형으로
# bang27_processed['추출시간'] = pd.to_datetime(bang27_processed['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
bang27_processed['가격'] = bang27_processed['가격'].str.replace(',', '').str.replace('원', '').astype(int)

bang27_processed
# Out:
#             항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0     타이에어아시아엑스  16:25  ICN  20:35  BKK   직항  06시간 10분    편도  274700
# 1        에어프레미아  17:10  ICN  21:15  BKK   직항  06시간 05분    편도  289400
# 2     타이에어아시아엑스  11:20  ICN  15:20  BKK   직항  06시간 00분    편도  305400
# 3          에어부산  16:50  ICN  21:10  BKK   직항  06시간 20분    편도  344224
# 4          제주항공  21:35  ICN  01:25  BKK   직항  05시간 50분    편도  352471
# ...         ...    ...  ...    ...  ...  ...       ...   ...     ...
# 3498       타이항공  10:50  ICN  14:45  BKK   직항  05시간 55분    편도  508316
# 3499       대한항공  09:15  ICN  13:15  BKK   직항  06시간 00분    편도  601154
# 3500     아시아나항공  10:50  ICN  14:45  BKK   직항  05시간 55분    편도  868491
# 3501     아시아나항공  17:30  ICN  21:25  BKK   직항  05시간 55분    편도  868491
# 3502     아시아나항공  09:35  ICN  13:30  BKK   직항  05시간 55분    편도  868491
#
#                     추출시간    편명         비행일자    사이트
# 0    2024-01-20 00:00:00  None  24.01.27(토)  naver
# ...

# %% [markdown]
# ### 편명 넣기

# %%
#타이에어아시아엑스
bang27_processed.loc[(bang27_processed['항공사'] == '타이에어아시아엑스') & (bang27_processed['출발시간'] == '16:25'), '편명'] = 'XJ 709'
bang27_processed.loc[(bang27_processed['항공사'] == '타이에어아시아엑스') & (bang27_processed['출발시간'] == '15:15'), '편명'] = 'XJ 701'

#에어프레미아, 에어부산, 이스타, 진에어, 티웨이
bang27_processed.loc[(bang27_processed['항공사'] == '에어프레미아') & (bang27_processed['출발시간'] == '17:10'), '편명'] = 'YP 601'
bang27_processed.loc[(bang27_processed['항공사'] == '에어부산') & (bang27_processed['출발시간'] == '16:50'), '편명'] = 'BX 747'
bang27_processed.loc[(bang27_processed['항공사'] == '이스타항공') & (bang27_processed['출발시간'] == '17:05'), '편명'] = 'ZE 511'
bang27_processed.loc[(bang27_processed['항공사'] == '진에어') & (bang27_processed['출발시간'] == '17:10'), '편명'] = 'LJ 3'
bang27_processed.loc[(bang27_processed['항공사'] == '티웨이항공') & (bang27_processed['출발시간'] == '19:50'), '편명'] = 'TW 101'

#한에어
bang27_processed.loc[(bang27_processed['항공사'] == '한에어') & (bang27_processed['출발시간'] == '21:35'), '편명'] = 'H1 9859'
bang27_processed.loc[(bang27_processed['항공사'] == '한에어') & (bang27_processed['출발시간'] == '19:50'), '편명'] = 'H1 5850'
bang27_processed.loc[(bang27_processed['항공사'] == '한에어') & (bang27_processed['출발시간'] == '19:30'), '편명'] = 'H1 9857'

#타이항공
bang27_processed.loc[(bang27_processed['항공사'] == '타이항공') & (bang27_processed['출발시간'] == '17:30'), '편명'] = 'TG 653'
bang27_processed.loc[(bang27_processed['항공사'] == '타이항공') & (bang27_processed['출발시간'] == '10:50'), '편명'] = 'TG 657'
bang27_processed.loc[(bang27_processed['항공사'] == '타이항공') & (bang27_processed['출발시간'] == '09:35'), '편명'] = 'TG 659'

#제주항공
bang27_processed.loc[(bang27_processed['항공사'] == '제주항공') & (bang27_processed['출발시간'] == '21:35'), '편명'] = '7C 2205'
bang27_processed.loc[(bang27_processed['항공사'] == '제주항공') & (bang27_processed['출발시간'] == '19:30'), '편명'] = '7C 2203'

#대한항공
bang27_processed.loc[(bang27_processed['항공사'] == '대한항공') & (bang27_processed['출발시간'] == '17:10'), '편명'] = 'KE 5065'
bang27_processed.loc[(bang27_processed['항공사'] == '대한항공') & (bang27_processed['출발시간'] == '09:15'), '편명'] = 'KE 657'
bang27_processed.loc[(bang27_processed['항공사'] == '대한항공') & (bang27_processed['출발시간'] == '17:20'), '편명'] = 'KE 651'
bang27_processed.loc[(bang27_processed['항공사'] == '대한항공') & (bang27_processed['출발시간'] == '20:10'), '편명'] = 'KE 673'
bang27_processed.loc[(bang27_processed['항공사'] == '대한항공') & (bang27_processed['출발시간'] == '20:35'), '편명'] = 'KE 659'
bang27_processed.loc[(bang27_processed['항공사'] == '대한항공') & (bang27_processed['출발시간'] == '19:05'), '편명'] = 'KE 653'

#아시아나항공
bang27_processed.loc[(bang27_processed['항공사'] == '아시아나항공') & (bang27_processed['출발시간'] == '09:35'), '편명'] = 'OZ 6761'
bang27_processed.loc[(bang27_processed['항공사'] == '아시아나항공') & (bang27_processed['출발시간'] == '10:50'), '편명'] = 'OZ 6737'
bang27_processed.loc[(bang27_processed['항공사'] == '아시아나항공') & (bang27_processed['출발시간'] == '18:05'), '편명'] = 'OZ 741'
bang27_processed.loc[(bang27_processed['항공사'] == '아시아나항공') & (bang27_processed['출발시간'] == '20:20'), '편명'] = 'OZ 743'
bang27_processed.loc[(bang27_processed['항공사'] == '아시아나항공') & (bang27_processed['출발시간'] == '17:30'), '편명'] = 'OZ 6763'

# %%
# bang27_processed[bang27_processed['편명'].isna()]
bang27_processed = bang27_processed.dropna()

bang27_processed[bang27_processed['편명'].isna()]

bang27_processed.to_csv('/home/subin/project/최종 raw/네이버 한국시간으로 처리 후 데이터/bang27_processed.csv', index=False)

# %% [markdown]
# ### 다낭 26 네이버 raw         (20일 00시 ~ 20일 18시 30분) + (20일 19시 ~ 22일 10시)

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']
#  편명, 비행일자, 사이트

dana26_processed= pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_danang_26.csv', names = col_names, encoding="utf-8")


dana26_processed['추출시간'] = pd.to_datetime(dana26_processed['추출시간'])

# '2024-01-20 12:30' 이전의 값에 대해서만 9시간을 더해줌
dana26_processed.loc[dana26_processed['추출시간'] < '2024-01-20 12:30', '추출시간'] += pd.Timedelta(hours=9)

dana26_processed['편명'] = None
dana26_processed['비행일자'] = '24.01.26(금)'
dana26_processed['사이트'] = 'naver'

# # 추출시간 date_time 형으로
# dana26_processed['추출시간'] = pd.to_datetime(dana26_processed['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
# 가격 , 원 제거 및 int 형으로
dana26_processed['가격'] = dana26_processed['가격'].str.replace(',', '').str.replace('원', '').astype(int)

dana26_processed
# Out:
#                           항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복  \
# 0                       비엣젯항공  22:40  ICN  01:45  DAD   직항  05시간 05분    편도
# 1                       이스타항공  20:55  ICN  23:45  DAD   직항  04시간 50분    편도
# 2                       비엣젯항공  07:00  ICN  10:05  DAD   직항  05시간 05분    편도
# 3                        에어서울  20:50  ICN  23:30  DAD   직항  04시간 40분    편도
# 4                       티웨이항공  20:20  ICN  23:35  DAD   직항  05시간 15분    편도
# ...                       ...    ...  ...    ...  ...  ...       ...   ...
# 2719                      한에어  06:15  ICN  09:20  DAD   직항  05시간 05분    편도
# 2720  Apg Distribution System  07:00  ICN  10:05  DAD   직항  05시간 05분    편도
# 2721                     대한항공  11:10  ICN  14:15  DAD   직항  05시간 05분    편도
# 2722                   아시아나항공  18:45  ICN  21:50  DAD   직항  05시간 05분    편도
# 2723  Apg Distribution System  06:15  ICN  09:20  DAD   직항  05시간 05분    편도
#
#           가격                추출시간    편명         비행일자    사이트
# ...

# %% [markdown]
# ### 편명 넣기

# %%
dana26_processed.loc[(dana26_processed['항공사'] == '비엣젯항공') & (dana26_processed['출발시간'] == '22:40'), '편명'] = 'VJ 875'
dana26_processed.loc[(dana26_processed['항공사'] == '이스타항공') & (dana26_processed['출발시간'] == '20:55'), '편명'] = 'ZE 593'
dana26_processed.loc[(dana26_processed['항공사'] == '비엣젯항공') & (dana26_processed['출발시간'] == '07:00'), '편명'] = 'VJ 879'
dana26_processed.loc[(dana26_processed['항공사'] == '에어서울') & (dana26_processed['출발시간'] == '20:50'), '편명'] = 'RS 511'
dana26_processed.loc[(dana26_processed['항공사'] == '티웨이항공') & (dana26_processed['출발시간'] == '20:20'), '편명'] = 'TW 127'
dana26_processed.loc[(dana26_processed['항공사'] == '티웨이항공') & (dana26_processed['출발시간'] == '19:25'), '편명'] = 'TW 191'
dana26_processed.loc[(dana26_processed['항공사'] == '티웨이항공') & (dana26_processed['출발시간'] == '07:45'), '편명'] = 'TW 125'

dana26_processed.loc[(dana26_processed['항공사'] == '베트남항공') & (dana26_processed['출발시간'] == '18:30'), '편명'] = 'VN 3441'

dana26_processed.loc[(dana26_processed['항공사'] == '베트남항공') & (dana26_processed['출발시간'] == '10:45'), '편명'] = 'VN 431'
dana26_processed.loc[(dana26_processed['항공사'] == '제주항공') & (dana26_processed['출발시간'] == '21:20'), '편명'] = '7C 2903'
dana26_processed.loc[(dana26_processed['항공사'] == '비엣젯항공') & (dana26_processed['출발시간'] == '06:15'), '편명'] = 'VJ 881'
dana26_processed.loc[(dana26_processed['항공사'] == '제주항공') & (dana26_processed['출발시간'] == '10:40'), '편명'] = '7C 2901'
dana26_processed.loc[(dana26_processed['항공사'] == '대한항공') & (dana26_processed['출발시간'] == '18:30'), '편명'] = 'KE 461'
dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '19:25'), '편명'] = 'H1 5885'
dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '07:45'), '편명'] = 'H1 5898'
dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '20:20'), '편명'] = 'H1 5914'
dana26_processed.loc[(dana26_processed['항공사'] == '제주항공') & (dana26_processed['출발시간'] == '11:40'), '편명'] = '7C 2901'

dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '21:20'), '편명'] = 'H1 9877'
dana26_processed.loc[(dana26_processed['항공사'] == '진에어') & (dana26_processed['출발시간'] == '21:10'), '편명'] = 'LJ 69'
dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '07:00'), '편명'] = 'H1 4069'
dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '22:40'), '편명'] = 'H1 4068'
dana26_processed.loc[(dana26_processed['항공사'] == '한에어') & (dana26_processed['출발시간'] == '06:15'), '편명'] = 'H1 4519'
dana26_processed.loc[(dana26_processed['항공사'] == 'dana26_20_00__22_10pg Distribution System') & (dana26_processed['출발시간'] == '07:00'), '편명'] = 'dana26_20_00__22_101 2879'
dana26_processed.loc[(dana26_processed['항공사'] == 'dana26_20_00__22_10pg Distribution System') & (dana26_processed['출발시간'] == '06:15'), '편명'] = 'dana26_20_00__22_101 2881'
# dana26_processed.loc[(dana26_processed['항공사'] == 'dana26_20_00__22_10pg Distribution System') & (dana26_processed['출발시간'] == '22:40'), '편명'] = ''

dana26_processed.loc[(dana26_processed['항공사'] == '대한항공') & (dana26_processed['출발시간'] == '11:10'), '편명'] = 'KE 457'
dana26_processed.loc[(dana26_processed['항공사'] == '아시아나항공') & (dana26_processed['출발시간'] == '18:45'), '편명'] = 'OZ 755'

# %%
# dana26_20_00__22_10[dana26_20_00__22_10['편명'].isna()]

# %%
# dana26_processed[dana26_processed['편명'].isna()]
dana26_processed = dana26_processed.dropna()

dana26_processed[dana26_processed['편명'].isna()]

dana26_processed.to_csv('/home/subin/project/최종 raw/네이버 한국시간으로 처리 후 데이터/dana26_processed.csv', index=False)

# %% [markdown]
# ### 다낭 27 네이버 raw
# ### 원이랑 ,는 이미 제거 되어 있음

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']
#  편명, 비행일자, 사이트

dana27_processed= pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_danang_27.csv', names = col_names, encoding="utf-8")


dana27_processed['추출시간'] = pd.to_datetime(dana27_processed['추출시간'])

# '2024-01-20 12:30' 이전의 값에 대해서만 9시간을 더해줌
dana27_processed.loc[dana27_processed['추출시간'] < '2024-01-20 12:30', '추출시간'] += pd.Timedelta(hours=9)

dana27_processed['편명'] = None
dana27_processed['비행일자'] = '24.01.27(토)'
dana27_processed['사이트'] = 'naver'

# # 추출시간 date_time 형으로
# dana27_processed['추출시간'] = pd.to_datetime(dana27_processed['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
#가격 , 원 제거 및 int 형으로
# dana27_processed['가격'] = dana27_processed['가격'].str.replace(',', '').str.replace('원', '').astype(int)

dana27_processed
# Out:
#          항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복       가격  \
# 0      이스타항공  22:50  ICN  01:30  DAD   직항  04시간 40분    편도   340651
# 1      이스타항공  20:55  ICN  23:45  DAD   직항  04시간 50분    편도   381864
# 2       에어서울  20:50  ICN  23:30  DAD   직항  04시간 40분    편도   422518
# 3      비엣젯항공  22:40  ICN  01:45  DAD   직항  05시간 05분    편도   512763
# 4      비엣젯항공  07:00  ICN  10:05  DAD   직항  05시간 05분    편도   512763
# ...      ...    ...  ...    ...  ...  ...       ...   ...      ...
# 3050     진에어  21:10  ICN  00:25  DAD   직항  05시간 15분    편도   605900
# 3051  아시아나항공  18:45  ICN  21:50  DAD   직항  05시간 05분    편도   735300
# 3052    대한항공  18:30  ICN  21:45  DAD   직항  05시간 15분    편도   756400
# 3053    대한항공  11:10  ICN  14:15  DAD   직항  05시간 05분    편도   756400
# 3054   베트남항공  18:30  ICN  21:45  DAD   직항  05시간 15분    편도  1347600
#
#                     추출시간    편명         비행일자    사이트
# 0    2024-01-20 00:00:00  None  24.01.27(토)  naver
# 1    2024-01-20 00:00:00  None  24.01.27(토)  naver
# ...

# %% [markdown]
# ### 편명 넣기

# %%
dana27_processed.loc[(dana27_processed['항공사'] == '비엣젯항공') & (dana27_processed['출발시간'] == '22:40'), '편명'] = 'VJ 875'
dana27_processed.loc[(dana27_processed['항공사'] == '이스타항공') & (dana27_processed['출발시간'] == '20:55'), '편명'] = 'ZE 593'
dana27_processed.loc[(dana27_processed['항공사'] == '비엣젯항공') & (dana27_processed['출발시간'] == '07:00'), '편명'] = 'VJ 879'
dana27_processed.loc[(dana27_processed['항공사'] == '에어서울') & (dana27_processed['출발시간'] == '20:50'), '편명'] = 'RS 511'
dana27_processed.loc[(dana27_processed['항공사'] == '티웨이항공') & (dana27_processed['출발시간'] == '20:20'), '편명'] = 'TW 127'
dana27_processed.loc[(dana27_processed['항공사'] == '티웨이항공') & (dana27_processed['출발시간'] == '19:25'), '편명'] = 'TW 191'
dana27_processed.loc[(dana27_processed['항공사'] == '티웨이항공') & (dana27_processed['출발시간'] == '07:45'), '편명'] = 'TW 125'

dana27_processed.loc[(dana27_processed['항공사'] == '베트남항공') & (dana27_processed['출발시간'] == '18:30'), '편명'] = 'VN 3441'

dana27_processed.loc[(dana27_processed['항공사'] == '베트남항공') & (dana27_processed['출발시간'] == '10:45'), '편명'] = 'VN 431'
dana27_processed.loc[(dana27_processed['항공사'] == '제주항공') & (dana27_processed['출발시간'] == '21:20'), '편명'] = '7C 2903'
dana27_processed.loc[(dana27_processed['항공사'] == '비엣젯항공') & (dana27_processed['출발시간'] == '06:15'), '편명'] = 'VJ 881'
dana27_processed.loc[(dana27_processed['항공사'] == '제주항공') & (dana27_processed['출발시간'] == '10:40'), '편명'] = '7C 2901'
dana27_processed.loc[(dana27_processed['항공사'] == '대한항공') & (dana27_processed['출발시간'] == '18:30'), '편명'] = 'KE 461'
dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '19:25'), '편명'] = 'H1 5885'
dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '07:45'), '편명'] = 'H1 5898'
dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '20:20'), '편명'] = 'H1 5914'
dana27_processed.loc[(dana27_processed['항공사'] == '제주항공') & (dana27_processed['출발시간'] == '11:40'), '편명'] = '7C 2901'

dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '21:20'), '편명'] = 'H1 9877'
dana27_processed.loc[(dana27_processed['항공사'] == '진에어') & (dana27_processed['출발시간'] == '21:10'), '편명'] = 'LJ 69'
dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '07:00'), '편명'] = 'H1 4069'
dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '22:40'), '편명'] = 'H1 4068'
dana27_processed.loc[(dana27_processed['항공사'] == '한에어') & (dana27_processed['출발시간'] == '06:15'), '편명'] = 'H1 4519'
dana27_processed.loc[(dana27_processed['항공사'] == 'dana27_20_00__22_10pg Distribution System') & (dana27_processed['출발시간'] == '07:00'), '편명'] = 'dana27_20_00__22_101 2879'
dana27_processed.loc[(dana27_processed['항공사'] == 'dana27_20_00__22_10pg Distribution System') & (dana27_processed['출발시간'] == '06:15'), '편명'] = 'dana27_20_00__22_101 2881'
# dana27_processed.loc[(dana27_processed['항공사'] == 'dana27_20_00__22_10pg Distribution System') & (dana27_processed['출발시간'] == '22:40'), '편명'] = ''

dana27_processed.loc[(dana27_processed['항공사'] == '대한항공') & (dana27_processed['출발시간'] == '11:10'), '편명'] = 'KE 457'
dana27_processed.loc[(dana27_processed['항공사'] == '아시아나항공') & (dana27_processed['출발시간'] == '18:45'), '편명'] = 'OZ 755'

# %%
# dana26_20_00__22_10[dana26_20_00__22_10['편명'].isna()]

# %%
# dana27_processed[dana27_processed['편명'].isna()]
dana27_processed = dana27_processed.dropna()

dana27_processed[dana27_processed['편명'].isna()]

dana27_processed.to_csv('/home/subin/amr_ws/eda/src/project/Raw_data/최종 raw/9시간 처리한거/dana27_processed.csv', index=False)

# %% [markdown]
# ### 오사카 26 네이버 raw

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']
#  편명, 비행일자, 사이트

osaka26_processed= pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_osaka_26.csv', names = col_names, encoding="utf-8")


osaka26_processed['추출시간'] = pd.to_datetime(osaka26_processed['추출시간'])

# '2024-01-20 12:30' 이전의 값에 대해서만 9시간을 더해줌
osaka26_processed.loc[osaka26_processed['추출시간'] < '2024-01-20 12:30', '추출시간'] += pd.Timedelta(hours=9)

osaka26_processed['편명'] = None
osaka26_processed['비행일자'] = '24.01.26(금)'
osaka26_processed['사이트'] = 'naver'

# # 추출시간 date_time 형으로
# osaka26_processed['추출시간'] = pd.to_datetime(osaka26_processed['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
#가격 , 원 제거 및 int 형으로
osaka26_processed['가격'] = osaka26_processed['가격'].str.replace(',', '').str.replace('원', '').astype(int)

osaka26_processed
# Out:
#        항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격  \
# 0     피치항공  15:25  ICN  17:10  KIX   직항  01시간 45분    편도  154705
# 1     에어서울  15:20  ICN  17:00  KIX   직항  01시간 40분    편도  170668
# 2     피치항공  07:30  ICN  09:15  KIX   직항  01시간 45분    편도  171239
# 3     피치항공  10:35  ICN  12:20  KIX   직항  01시간 45분    편도  171239
# 4     에어부산  15:35  ICN  17:30  KIX   직항  01시간 55분    편도  179758
# ...    ...    ...  ...    ...  ...  ...       ...   ...     ...
# 5677  일본항공  19:05  ICN  21:00  KIX   직항  01시간 55분    편도  366200
# 5678   ANA  08:05  ICN  09:40  KIX   직항  01시간 35분    편도  366700
# 5679   ANA  14:10  ICN  15:50  KIX   직항  01시간 40분    편도  366700
# 5680   ANA  19:10  ICN  20:55  KIX   직항  01시간 45분    편도  366700
# 5681  일본항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  376000
#
#                     추출시간    편명         비행일자    사이트
# 0    2024-01-20 00:00:00  None  24.01.26(금)  naver
# 1    2024-01-20 00:00:00  None  24.01.26(금)  naver
# ...

# %% [markdown]
# ### 편명 넣기

# %%
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "피치항공" and
        osaka26_processed["출발시간"][i] == "15:25" and
        osaka26_processed["도착시간"][i] == "17:10"):
            osaka26_processed["편명"][i] = "MM 706"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "이스타항공" and
        osaka26_processed["출발시간"][i] == "15:05" and
        osaka26_processed["도착시간"][i] == "17:00"):
            osaka26_processed["편명"][i] = "ZE 613"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "피치항공" and
        osaka26_processed["출발시간"][i] == "10:35" and
        osaka26_processed["도착시간"][i] == "12:20"):
            osaka26_processed["편명"][i] = "MM 702"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "진에어" and
        osaka26_processed["출발시간"][i] == "14:05" and
        osaka26_processed["도착시간"][i] == "16:00"):
            osaka26_processed["편명"][i] = "LJ 241"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "에어서울" and
        osaka26_processed["출발시간"][i] == "15:20" and
        osaka26_processed["도착시간"][i] == "17:00"):
            osaka26_processed["편명"][i] = "RS 715"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "에어서울" and
        osaka26_processed["출발시간"][i] == "13:10" and
        osaka26_processed["도착시간"][i] == "15:00"):
            osaka26_processed["편명"][i] = "RS 713"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "티웨이항공" and
        osaka26_processed["출발시간"][i] == "14:40" and
        osaka26_processed["도착시간"][i] == "16:30"):
            osaka26_processed["편명"][i] = "TW 285"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "티웨이항공" and
        osaka26_processed["출발시간"][i] == "12:10" and
        osaka26_processed["도착시간"][i] == "14:00"):
            osaka26_processed["편명"][i] = "TW 283"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "진에어" and
        osaka26_processed["출발시간"][i] == "15:00" and
        osaka26_processed["도착시간"][i] == "16:40"):
            osaka26_processed["편명"][i] = "LJ 239"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "09:10" and
        osaka26_processed["도착시간"][i] == "11:00"):
            osaka26_processed["편명"][i] = "H1 9811"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "제주항공" and
        osaka26_processed["출발시간"][i] == "07:00" and
        osaka26_processed["도착시간"][i] == "09:00"):
            osaka26_processed["편명"][i] = "7C 1304"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "제주항공" and
        osaka26_processed["출발시간"][i] == "09:40" and
        osaka26_processed["도착시간"][i] == "11:30"):
            osaka26_processed["편명"][i] = "7C 1308"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "이스타항공" and
        osaka26_processed["출발시간"][i] == "09:05" and
        osaka26_processed["도착시간"][i] == "10:55"):
            osaka26_processed["편명"][i] = "ZE 611"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "피치항공" and
        osaka26_processed["출발시간"][i] == "07:30" and
        osaka26_processed["도착시간"][i] == "09:15"):
            osaka26_processed["편명"][i] = "MM 712"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "에어부산" and
        osaka26_processed["출발시간"][i] == "12:35" and
        osaka26_processed["도착시간"][i] == "14:25"):
            osaka26_processed["편명"][i] = "BX 174"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "제주항공" and
        osaka26_processed["출발시간"][i] == "16:55" and
        osaka26_processed["도착시간"][i] == "18:40"):
            osaka26_processed["편명"][i] = "7C 1306"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "아시아나항공" and
        osaka26_processed["출발시간"][i] == "14:10" and
        osaka26_processed["도착시간"][i] == "15:50"):
            osaka26_processed["편명"][i] = "OZ 114"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "대한항공" and
        osaka26_processed["출발시간"][i] == "15:10" and
        osaka26_processed["도착시간"][i] == "17:00"):
            osaka26_processed["편명"][i] = "KE 725"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "에어부산" and
        osaka26_processed["출발시간"][i] == "15:35" and
        osaka26_processed["도착시간"][i] == "17:30"):
            osaka26_processed["편명"][i] = "BX 176"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "에어서울" and
        osaka26_processed["출발시간"][i] == "07:15" and
        osaka26_processed["도착시간"][i] == "09:05"):
            osaka26_processed["편명"][i] = "RS 711"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "티웨이항공" and
        osaka26_processed["출발시간"][i] == "07:55" and
        osaka26_processed["도착시간"][i] == "09:45"):
            osaka26_processed["편명"][i] = "TW 281"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "제주항공" and
        osaka26_processed["출발시간"][i] == "09:10" and
        osaka26_processed["도착시간"][i] == "11:00"):
            osaka26_processed["편명"][i] = "7C 1302"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "진에어" and
        osaka26_processed["출발시간"][i] == "08:00" and
        osaka26_processed["도착시간"][i] == "09:45"):
            osaka26_processed["편명"][i] = "LJ 233"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "아시아나항공" and
        osaka26_processed["출발시간"][i] == "08:05" and
        osaka26_processed["도착시간"][i] == "09:40"):
            osaka26_processed["편명"][i] = "OZ 112"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "대한항공" and
        osaka26_processed["출발시간"][i] == "19:05" and
        osaka26_processed["도착시간"][i] == "21:00"):
            osaka26_processed["편명"][i] = "KE 721"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "제주항공" and
        osaka26_processed["출발시간"][i] == "16:55" and
        osaka26_processed["도착시간"][i] == "18:40"):
            osaka26_processed["편명"][i] = "7C 1306"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "피치항공" and
        osaka26_processed["출발시간"][i] == "21:00" and
        osaka26_processed["도착시간"][i] == "22:45"):
            osaka26_processed["편명"][i] = "MM 710"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "아시아나항공" and
        osaka26_processed["출발시간"][i] == "19:10" and
        osaka26_processed["도착시간"][i] == "20:55"):
            osaka26_processed["편명"][i] = "OZ 116"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "대한항공" and
        osaka26_processed["출발시간"][i] == "09:00" and
        osaka26_processed["도착시간"][i] == "10:45"):
            osaka26_processed["편명"][i] = "KE 723"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "대한항공" and
        osaka26_processed["출발시간"][i] == "10:45" and
        osaka26_processed["도착시간"][i] == "12:30"):
            osaka26_processed["편명"][i] = "KE 727"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "대한항공" and
        osaka26_processed["출발시간"][i] == "10:45" and
        osaka26_processed["도착시간"][i] == "12:30"):
            osaka26_processed["편명"][i] = "KE 727"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "07:55" and
        osaka26_processed["도착시간"][i] == "09:45"):
            osaka26_processed["편명"][i] = "H1 5868"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "14:40" and
        osaka26_processed["도착시간"][i] == "16:30"):
            osaka26_processed["편명"][i] = "H1 5926"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "12:10" and
        osaka26_processed["도착시간"][i] == "14:00"):
            osaka26_processed["편명"][i] = "H1 5881"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "12:10" and
        osaka26_processed["도착시간"][i] == "14:00"):
            osaka26_processed["편명"][i] = "H1 5881"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "ANA" and
        osaka26_processed["출발시간"][i] == "08:05" and
        osaka26_processed["도착시간"][i] == "09:40"):
            osaka26_processed["편명"][i] = "NH 6952"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "ANA" and
        osaka26_processed["출발시간"][i] == "14:10" and
        osaka26_processed["도착시간"][i] == "15:50"):
            osaka26_processed["편명"][i] = "NH 6954"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "일본항공" and
        osaka26_processed["출발시간"][i] == "09:00" and
        osaka26_processed["도착시간"][i] == "10:45"):
            osaka26_processed["편명"][i] = "JL 5210"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "일본항공" and
        osaka26_processed["출발시간"][i] == "15:10" and
        osaka26_processed["도착시간"][i] == "17:00"):
            osaka26_processed["편명"][i] = "JL 5212"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "일본항공" and
        osaka26_processed["출발시간"][i] == "19:05" and
        osaka26_processed["도착시간"][i] == "21:00"):
            osaka26_processed["편명"][i] = "JL 5214"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "ANA" and
        osaka26_processed["출발시간"][i] == "19:10" and
        osaka26_processed["도착시간"][i] == "20:55"):
            osaka26_processed["편명"][i] = "NH 6956"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "일본항공" and
        osaka26_processed["출발시간"][i] == "10:45" and
        osaka26_processed["도착시간"][i] == "12:30"):
            osaka26_processed["편명"][i] = "JL 5270"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "16:55" and
        osaka26_processed["도착시간"][i] == "18:40"):
            osaka26_processed["편명"][i] = "H1 9815"
for i in range(len(osaka26_processed)):
    if (osaka26_processed["항공사"][i] == "한에어" and
        osaka26_processed["출발시간"][i] == "07:00" and
        osaka26_processed["도착시간"][i] == "09:00"):
            osaka26_processed["편명"][i] = "H1 9813"
# Out:
# /tmp/ipykernel_391919/3093410883.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osaka26_processed["편명"][i] = "MM 706"
# /tmp/ipykernel_391919/3093410883.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osaka26_processed["편명"][i] = "MM 706"
# /tmp/ipykernel_391919/3093410883.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osaka26_processed["편명"][i] = "MM 706"
# ...

# %%
# osaka26_processed[osaka26_processed['편명'].isna()]
osaka26_processed = osaka26_processed.dropna()

osaka26_processed[osaka26_processed['편명'].isna()]

osaka26_processed.to_csv('/home/subin/project/최종 raw/네이버 한국시간으로 처리 후 데이터/osaka26_processed.csv', index=False)

# %% [markdown]
# ### 오사카 27 네이버 raw         (20일 00시 ~ 20일 18시 30분) + (20일 19시 ~ 22일 10시)

# %%
col_names = ['항공사', '출발시간', '출발공항', '도착시간', '도착공항',
            '비행방식', '소요시간', '편도/왕복', '가격', '추출시간']
#  편명, 비행일자, 사이트

osaka27_processed= pd.read_csv(f'/home/subin/project/최종 raw/Naver_raw_data/naver_osaka_27.csv', names = col_names, encoding="utf-8")


osaka27_processed['추출시간'] = pd.to_datetime(osaka27_processed['추출시간'])

# '2024-01-20 12:30' 이전의 값에 대해서만 9시간을 더해줌
osaka27_processed.loc[osaka27_processed['추출시간'] < '2024-01-20 12:30', '추출시간'] += pd.Timedelta(hours=9)

osaka27_processed['편명'] = None
osaka27_processed['비행일자'] = '24.01.27(토)'
osaka27_processed['사이트'] = 'naver'

# # 추출시간 date_time 형으로
# osaka27_processed['추출시간'] = pd.to_datetime(osaka27_processed['추출시간'], format='%Y-%m-%d %H:%M', errors='raise')
#가격 , 원 제거 및 int 형으로
# osaka27_processed['가격'] = osaka27_processed['가격'].str.replace(',', '').str.replace('원', '').astype(int)

osaka27_processed
# Out:
#         항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격       추출시간  \
# 0      에어서울  15:25  ICN  17:10  KIX   직항  01시간 45분    편도  154705 2024-01-20
# 1      에어서울  15:20  ICN  17:00  KIX   직항  01시간 40분    편도  170668 2024-01-20
# 2      피치항공  10:35  ICN  12:20  KIX   직항  01시간 45분    편도  171239 2024-01-20
# 3      피치항공  07:30  ICN  09:15  KIX   직항  01시간 45분    편도  171239 2024-01-20
# 4     티웨이항공  14:40  ICN  16:30  KIX   직항  01시간 50분    편도  184300 2024-01-20
# ...     ...    ...  ...    ...  ...  ...       ...   ...     ...        ...
# 6226   일본항공  19:05  ICN  21:00  KIX   직항  01시간 55분    편도  361142 2024-01-23
# 6227   일본항공  09:00  ICN  10:45  KIX   직항  01시간 45분    편도  361273 2024-01-23
# 6228   일본항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  508128 2024-01-23
# 6229   대한항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  528292 2024-01-23
# 6230   대한항공  08:00  ICN  09:45  KIX   직항  01시간 45분    편도  531374 2024-01-23
#
#         편명         비행일자    사이트
# ...

# %% [markdown]
# ### 편명 넣기

# %%
osaka27_processed.loc[(osaka27_processed['항공사'] == '피치항공') & (osaka27_processed['출발시간'] == '15:25'), '편명'] = 'MM 706'
osaka27_processed.loc[(osaka27_processed['항공사'] == '피치항공') & (osaka27_processed['출발시간'] == '07:30'), '편명'] = 'MM 712'
osaka27_processed.loc[(osaka27_processed['항공사'] == '피치항공') & (osaka27_processed['출발시간'] == '10:35'), '편명'] = 'MM 702'
osaka27_processed.loc[(osaka27_processed['항공사'] == '피치항공') & (osaka27_processed['출발시간'] == '21:00'), '편명'] = 'MM 710'

osaka27_processed.loc[(osaka27_processed['항공사'] == '에어서울') & (osaka27_processed['출발시간'] == '15:20'), '편명'] = 'RS 715'
osaka27_processed.loc[(osaka27_processed['항공사'] == '에어서울') & (osaka27_processed['출발시간'] == '13:10'), '편명'] = 'RS 713'
osaka27_processed.loc[(osaka27_processed['항공사'] == '에어서울') & (osaka27_processed['출발시간'] == '07:15'), '편명'] = 'RS 711'

osaka27_processed.loc[(osaka27_processed['항공사'] == '에어부산') & (osaka27_processed['출발시간'] == '12:35'), '편명'] = 'BX 174'
osaka27_processed.loc[(osaka27_processed['항공사'] == '에어부산') & (osaka27_processed['출발시간'] == '15:35'), '편명'] = 'BX 176'
osaka27_processed.loc[(osaka27_processed['항공사'] == '에어부산') & (osaka27_processed['출발시간'] == '09:45'), '편명'] = 'BX 172'

osaka27_processed.loc[(osaka27_processed['항공사'] == '티웨이항공') & (osaka27_processed['출발시간'] == '14:40'), '편명'] = 'TW 285'
osaka27_processed.loc[(osaka27_processed['항공사'] == '티웨이항공') & (osaka27_processed['출발시간'] == '12:10'), '편명'] = 'TW 283'
osaka27_processed.loc[(osaka27_processed['항공사'] == '티웨이항공') & (osaka27_processed['출발시간'] == '07:55'), '편명'] = 'TW 281'

osaka27_processed.loc[(osaka27_processed['항공사'] == '이스타항공') & (osaka27_processed['출발시간'] == '15:05'), '편명'] = 'ZE 613'
osaka27_processed.loc[(osaka27_processed['항공사'] == '이스타항공') & (osaka27_processed['출발시간'] == '09:05'), '편명'] = 'ZE 611'

osaka27_processed.loc[(osaka27_processed['항공사'] == '진에어') & (osaka27_processed['출발시간'] == '15:00'), '편명'] = 'LJ 239'
osaka27_processed.loc[(osaka27_processed['항공사'] == '진에어') & (osaka27_processed['출발시간'] == '12:25'), '편명'] = 'LJ 241'
osaka27_processed.loc[(osaka27_processed['항공사'] == '진에어') & (osaka27_processed['출발시간'] == '08:00'), '편명'] = 'LJ 233'
osaka27_processed.loc[(osaka27_processed['항공사'] == '진에어') & (osaka27_processed['출발시간'] == '08:55'), '편명'] = 'LJ 235'

osaka27_processed.loc[(osaka27_processed['항공사'] == '제주항공') & (osaka27_processed['출발시간'] == '16:55'), '편명'] = '7C 1306'
osaka27_processed.loc[(osaka27_processed['항공사'] == '제주항공') & (osaka27_processed['출발시간'] == '07:00'), '편명'] = '7C 1304'
osaka27_processed.loc[(osaka27_processed['항공사'] == '제주항공') & (osaka27_processed['출발시간'] == '09:10'), '편명'] = '7C 1302'
osaka27_processed.loc[(osaka27_processed['항공사'] == '제주항공') & (osaka27_processed['출발시간'] == '09:40'), '편명'] = '7C 1308'

osaka27_processed.loc[(osaka27_processed['항공사'] == '대한항공') & (osaka27_processed['출발시간'] == '19:05'), '편명'] = 'KE 721'
osaka27_processed.loc[(osaka27_processed['항공사'] == '대한항공') & (osaka27_processed['출발시간'] == '15:10'), '편명'] = 'KE 725'
osaka27_processed.loc[(osaka27_processed['항공사'] == '대한항공') & (osaka27_processed['출발시간'] == '09:00'), '편명'] = 'KE 723'
osaka27_processed.loc[(osaka27_processed['항공사'] == '대한항공') & (osaka27_processed['출발시간'] == '10:45'), '편명'] = 'KE 727'
osaka27_processed.loc[(osaka27_processed['항공사'] == '대한항공') & (osaka27_processed['출발시간'] == '08:00'), '편명'] = 'KE 5071'


osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '16:55'), '편명'] = 'H1 9815'
osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '07:00'), '편명'] = 'H1 9813'
osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '14:40'), '편명'] = 'H1 5926'
osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '07:55'), '편명'] = 'H1 5868'
osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '12:10'), '편명'] = 'H1 5881'
osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '09:10'), '편명'] = 'H1 9811'
osaka27_processed.loc[(osaka27_processed['항공사'] == '한에어') & (osaka27_processed['출발시간'] == '09:40'), '편명'] = 'H1 9926'

osaka27_processed.loc[(osaka27_processed['항공사'] == '아시아나항공') & (osaka27_processed['출발시간'] == '19:10'), '편명'] = 'OZ 116'
osaka27_processed.loc[(osaka27_processed['항공사'] == '아시아나항공') & (osaka27_processed['출발시간'] == '12:25'), '편명'] = 'OZ 118'
osaka27_processed.loc[(osaka27_processed['항공사'] == '아시아나항공') & (osaka27_processed['출발시간'] == '14:10'), '편명'] = 'OZ 114'
osaka27_processed.loc[(osaka27_processed['항공사'] == '아시아나항공') & (osaka27_processed['출발시간'] == '08:05'), '편명'] = 'OZ 112'

osaka27_processed.loc[(osaka27_processed['항공사'] == '일본항공') & (osaka27_processed['출발시간'] == '09:00'), '편명'] = 'JL 5210'
osaka27_processed.loc[(osaka27_processed['항공사'] == '일본항공') & (osaka27_processed['출발시간'] == '19:05'), '편명'] = 'JL 5214'
osaka27_processed.loc[(osaka27_processed['항공사'] == '일본항공') & (osaka27_processed['출발시간'] == '10:45'), '편명'] = 'JL 5270'
osaka27_processed.loc[(osaka27_processed['항공사'] == '일본항공') & (osaka27_processed['출발시간'] == '15:10'), '편명'] = 'JL 5212'

osaka27_processed.loc[(osaka27_processed['항공사'] == 'ANA') & (osaka27_processed['출발시간'] == '19:10'), '편명'] = 'NH 6956'
osaka27_processed.loc[(osaka27_processed['항공사'] == 'ANA') & (osaka27_processed['출발시간'] == '14:10'), '편명'] = 'NH 6954'
osaka27_processed.loc[(osaka27_processed['항공사'] == 'ANA') & (osaka27_processed['출발시간'] == '08:05'), '편명'] = 'NH 6952'

# %%
osaka27_processed
# Out:
#         항공사   출발시간 출발공항   도착시간 도착공항 비행방식      소요시간 편도/왕복      가격       추출시간  \
# 1      에어서울  15:20  ICN  17:00  KIX   직항  01시간 40분    편도  170668 2024-01-20
# 2      피치항공  10:35  ICN  12:20  KIX   직항  01시간 45분    편도  171239 2024-01-20
# 3      피치항공  07:30  ICN  09:15  KIX   직항  01시간 45분    편도  171239 2024-01-20
# 4     티웨이항공  14:40  ICN  16:30  KIX   직항  01시간 50분    편도  184300 2024-01-20
# 5     티웨이항공  12:10  ICN  14:00  KIX   직항  01시간 50분    편도  184361 2024-01-20
# ...     ...    ...  ...    ...  ...  ...       ...   ...     ...        ...
# 6226   일본항공  19:05  ICN  21:00  KIX   직항  01시간 55분    편도  361142 2024-01-23
# 6227   일본항공  09:00  ICN  10:45  KIX   직항  01시간 45분    편도  361273 2024-01-23
# 6228   일본항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  508128 2024-01-23
# 6229   대한항공  10:45  ICN  12:30  KIX   직항  01시간 45분    편도  528292 2024-01-23
# 6230   대한항공  08:00  ICN  09:45  KIX   직항  01시간 45분    편도  531374 2024-01-23
#
#            편명         비행일자    사이트
# ...

# %%
# osaka27_processed[osaka27_processed['편명'].isna()]
osaka27_processed = osaka27_processed.dropna()

osaka27_processed[osaka27_processed['편명'].isna()]

osaka27_processed.to_csv('/home/subin/project/최종 raw/네이버 한국시간으로 처리 후 데이터/osaka27_processed.csv', index=False)
